# %%
import torch
import sys
sys.path.append('..')
import matplotlib.pyplot as plt

# %%
#a = torch.load(f'../saved_models/testing/rml/long/e4/12/coefficients.pt')
d4_49 = torch.load(f'../saved_models/testing/rml/long/e4/49/training_losses.pt')
d5_49= torch.load(f'../saved_models/testing/rml/long/e5/49/training_losses.pt')
#compare1 = torch.load(f'../saved_models/get/testing/rml/long/e4/70/training_losses.pt')
#compare2 = torch.load(f'../saved_models/get/testing/rml/long/exp1/e4/70/training_losses.pt')
#compare3 = torch.load(f'../saved_models/get/testing/rml/long/exp2/e4/70/training_losses.pt')
#ma_4_60 = torch.load(f'../saved_models/testing/rml/ma/e4/61/training_losses.pt')
#ma_5_60 = torch.load(f'../saved_models/testing/rml/ma/e5/61/training_losses.pt')

map_e4 = torch.load(f'../saved_models/testing/map/long/e4/0/training_losses.pt') 
map_e5 = torch.load(f'../saved_models/testing/map/long/e5/0/training_losses.pt')

# %%
num=20

# %%
data4 = torch.load(f'../data/@/1.0e+04/data/data.pt')
data5 = torch.load(f'../data/@/1.0e+05/data/data.pt')

# %%
data4_x_data_reg_noise = torch.load(f'../data/@/1.0e+04/rml_noise/{num}/noise_data_regularization.pt')
data4_x_data_noise = torch.load(f'../data/@/1.0e+04/rml_noise/{num}/noise_data.pt')
data4_x_param_noise = torch.load(f'../data/@/1.0e+04/rml_noise/{num}/noise_parameter.pt')

data5_x_data_reg_noise = torch.load(f'../data/@/1.0e+05/rml_noise/{num}/noise_data_regularization.pt')
data5_x_data_noise = torch.load(f'../data/@/1.0e+05/rml_noise/{num}/noise_data.pt')
data5_x_param_noise = torch.load(f'../data/@/1.0e+05/rml_noise/{num}/noise_parameter.pt')

# %%
d4_0 = torch.load(f'../saved_models/testing/rml/long/e4/13/training_losses.pt')
d5_0 = torch.load(f'../saved_models/testing/rml/long/e5/13/training_losses.pt')
d4_0_coeff = torch.load(f'../saved_models/testing/rml/long/e4/13/coefficients.pt')
d5_0_coeff = torch.load(f'../saved_models/testing/rml/long/e5/13/coefficients.pt')

# %%
d4_0[100,1]
# Out:
# tensor(9., grad_fn=<SelectBackward0>)

# %%
print(d4_0_coeff)
print(d5_0_coeff)
# Out:
# tensor([100.0000,   1.0000,   1.1111])
# tensor([100.0000,   1.0000,   0.1111])

# %%
#time4 = d4_0[:,0]
#total4 = d4_0[:,1]
#residual4 = d4_0[:,2]
#time5 = d5_0[:,0]
#total5 = d5_0[:,1]
#residual5 = d5_0[:,2]

#plt.plot(time.detach(), total.detach())
type_ = 1
plt.figure(1)
from_ = 1
#plt.yscale('log')
plt.plot(ma_4_60[from_:,0].detach(), ma_5_60[from_:,type_].detach(), 'b')
plt.figure(2)
#plt.yscale('log')
plt.plot(ma_5_60[from_:,0].detach(), ma_5_60[from_:,type_].detach(), 'k')

# %%
#time4 = d4_0[:,0]
#total4 = d4_0[:,1]
#residual4 = d4_0[:,2]
#time5 = d5_0[:,0]
#total5 = d5_0[:,1]
#residual5 = d5_0[:,2]

#plt.plot(time.detach(), total.detach())
type_ = 1
plt.figure(1)
from_ = 500
#plt.yscale('log')
plt.plot(compare1[from_:,0].detach(), compare1[from_:,type_].detach(), 'b')
#plt.figure(2)
#plt.yscale('log')
plt.plot(compare2[from_:,0].detach(), compare2[from_:,type_+1].detach(), 'r')
#plt.figure(3)
plt.plot(compare3[from_:,0].detach(), compare3[from_:,type_+1].detach(), 'k')

# %%
torch.save(torch.Tensor([0]), f'finished_{0}.pt')

# %%
save_path_run = ''
run = 0
torch.save(torch.Tensor([0]), f'{save_path_run}finished_{run}.pt')

# %%
#time4 = d4_0[:,0]
#total4 = d4_0[:,1]
#residual4 = d4_0[:,2]
#time5 = d5_0[:,0]
#total5 = d5_0[:,1]
#residual5 = d5_0[:,2]

#plt.plot(time.detach(), total.detach())
type_ = 2
plt.figure(1)
from_ = 500
#plt.yscale('log')
plt.plot(map_e4[from_:,0].detach(), map_e4[from_:,type_].detach(), 'b')
plt.figure(2)
#plt.yscale('log')
plt.plot(map_e5[from_:,0].detach(), map_e5[from_:,type_].detach(), 'k')
