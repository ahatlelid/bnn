# %%
import torch
sys.path.append("..")
import matplotlib.pyplot as plt
import numpy as np

# %%
a = torch.load('../data/1.0e+05/data/data.pt')

# %%
b = torch.load

# %%
tensor_n_masked = torch.randint(1, 10+1, (10,))
tensor_n_masked
# Out:
# tensor([ 3,  6,  2,  9, 10,  9,  8,  4,  4,  3])

# %%
a = torch.load('../data/1.0e+05/data/data.pt')
a = a[:,:10]
plt.hist(a[np.abs(a)>0.00001].flatten(), bins=200)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 2.000e+00,
#         2.000e+00, 1.000e+00, 3.000e+00, 5.000e+00, 3.000e+00, 5.000e+00,
#         5.000e+00, 6.000e+00, 1.000e+01, 1.100e+01, 6.000e+00, 1.300e+01,
#         2.300e+01, 2.400e+01, 4.000e+01, 3.800e+01, 4.600e+01, 3.800e+01,
#         5.300e+01, 7.300e+01, 5.600e+01, 7.200e+01, 1.090e+02, 1.170e+02,
#         1.500e+02, 1.520e+02, 1.710e+02, 2.000e+02, 2.180e+02, 2.950e+02,
#         3.170e+02, 3.620e+02, 4.070e+02, 4.250e+02, 5.010e+02, 5.820e+02,
#         6.360e+02, 7.390e+02, 7.980e+02, 8.520e+02, 9.430e+02, 1.118e+03,
#         1.218e+03, 1.398e+03, 1.545e+03, 1.616e+03, 1.724e+03, 1.947e+03,
#         2.105e+03, 2.282e+03, 2.494e+03, 2.708e+03, 3.009e+03, 3.145e+03,
#         3.301e+03, 3.659e+03, 3.724e+03, 4.197e+03, 4.473e+03, 4.666e+03,
# ...
