# %%
import sys
sys.path.append("..")

from utils.model import Net_mask
#from utils.model4 import Net_mask
import torch

import matplotlib.pyplot as plt

# %%
model_file = "../saved_models/models_infinite_data/ML/model_weights.pth"
model_file_reg = "../saved_models/models_infinite_data/MAP_inf_prior_100/model_weights.pth"
#model_file = "../saved_models/finite_long_e5/map/0/model_weights.pth"
#model_file = "../saved_models/infinite_test/model_weights.pth"
model = Net_mask()
model_reg = Net_mask()
model.load_state_dict(torch.load(model_file))
model_reg.load_state_dict(torch.load(model_file_reg))
# Out:
# <All keys matched successfully>

# %%
test_obses = torch.load('../data/test_observations/all_test_observations.pt')
test_solution = torch.load('../data/test_observations/all_test_solutions.pt')

# %%
num_points = 3
for j in range(6):
    ind = int(f'{num_points}{j}')
    y = test_obses[ind,:10]
    mask = test_obses[ind,10:]
    mask_bool = mask > 0.5
    points = torch.where(mask_bool)[0]
    values = y[mask_bool]

    test_obs = test_obses[ind]
    out = model(test_obs)

    plt.figure()
    plt.plot(range(10), test_solution[ind])
    plt.plot(range(10), out.detach().numpy())
    plt.plot(points, values, 'bo')
    plt.axis([-0.5, 9.5, -2.5, 2.5])

# %%
#num_points = 3
j = 0
for num_points in range(1, 7):
    ind = int(f'{num_points}{j}')
    y = test_obses[ind,:10]
    mask = test_obses[ind,10:]
    mask_bool = mask > 0.5
    points = torch.where(mask_bool)[0]
    values = y[mask_bool]

    test_obs = test_obses[ind]
    out = model(test_obs)
    out_reg = model_reg(test_obs)

    plt.figure()
    plt.title(f'ML-inf, MAP-inf and analytical, {num_points} data points')
    if num_points == 1:
        plt.title(f'ML-inf vs analytical, {num_points} data point')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.plot(range(10), test_solution[ind], 'b')
    plt.plot(range(10), out_reg.detach().numpy(), 'r')
    plt.plot(range(10), out.detach().numpy(), 'g')
    plt.plot(points, values, 'ko')
    plt.legend(['analytical', 'MAP-inf', 'ML-inf', 'data point'])
    plt.axis([-0.5, 9.5, -2.5, 2.5])
    plt.savefig(f'../figures/plot_ML-inf_vs_analytical/plot_ML-inf_vs_analytical_{num_points}.png')
